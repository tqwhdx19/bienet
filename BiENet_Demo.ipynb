# %%
# !bash tools/dist_train.sh /HDD01/tangqian/code/mmseg-bienet/RS_configs/inria_bienet_512-160k.py 4
# Out:
# /home/amax/anaconda3/envs/openmmlab/lib/python3.8/site-packages/torch/distributed/launch.py:181: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use-env is set by default in torchrun.
# If your script expects `--local-rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# [2024-10-12 22:28:50,891] torch.distributed.run: [WARNING]
# [2024-10-12 22:28:50,891] torch.distributed.run: [WARNING] *****************************************
# [2024-10-12 22:28:50,891] torch.distributed.run: [WARNING] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# ...

# %%
# !bash tools/dist_test.sh  /HDD01/tangqian/code/mmseg-bienet/RS_configs/inria_bienet_512-160k.py /HDD01/tangqian/code/mmseg-bienet/work_dirs/inria-bienet-v4-160k/best_mIoU_iter_119500.pth  2 --tta
# Out:
# /home/amax/anaconda3/envs/openmmlab/lib/python3.8/site-packages/torch/distributed/launch.py:181: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use-env is set by default in torchrun.
# If your script expects `--local-rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# [2024-10-14 07:58:45,850] torch.distributed.run: [WARNING]
# [2024-10-14 07:58:45,850] torch.distributed.run: [WARNING] *****************************************
# [2024-10-14 07:58:45,850] torch.distributed.run: [WARNING] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# ...
